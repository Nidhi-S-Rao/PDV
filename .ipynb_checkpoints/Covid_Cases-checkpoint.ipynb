# %%
import requests
from bs4 import BeautifulSoup
import csv
url = 'https://www.worldometers.info/coronavirus/countries-where-coronavirus-has-spread/'

# get URL's html
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
data = []

data_iterator = iter(soup.find_all('td'))
# data_iterator is the iterator of the table
data_iterator

# %%
# This loop will keep repeating till there is data available in the iterator
while True:
    try:
        data_dict={}
        data_dict['country'] = next(data_iterator).text
        data_dict['confirmed'] = int(next(data_iterator).text.replace(',',''))
        data_dict['deaths'] = int(next(data_iterator).text.replace(',',''))
        data_dict['continent'] = next(data_iterator).text

        data.append(data_dict)

# StopIteration error is raised when there are no more elements left to iterate through
    except StopIteration:
        break
data
# Out:
# [{'country': 'United States',
#   'confirmed': 108926862,
#   'deaths': 1178851,
#   'continent': 'North America'},
#  {'country': 'India',
#   'confirmed': 44999561,
#   'deaths': 531930,
#   'continent': 'Asia'},
#  {'country': 'France',
#   'confirmed': 40138560,
#   'deaths': 167642,
#   'continent': 'Europe'},
#  {'country': 'Germany',
#   'confirmed': 38514765,
#   'deaths': 176314,
#   'continent': 'Europe'},
#  {'country': 'Brazil',
#   'confirmed': 37849919,
#   'deaths': 706142,
#   'continent': 'South America'},
#  {'country': 'South Korea',
#   'confirmed': 34571873,
#   'deaths': 35934,
#   'continent': 'Asia'},
#  {'country': 'Japan (+Diamond Princess)',
#   'confirmed': 33804284,
#   'deaths': 74707,
#   'continent': 'Asia'},
#  {'country': 'Italy',
#   'confirmed': 26168412,
#   'deaths': 192013,
#   'continent': 'Europe'},
#  {'country': 'United Kingdom',
#   'confirmed': 24743787,
#   'deaths': 229765,
#   'continent': 'Europe'},
#  {'country': 'Russia',
# ...

# %%
filename = 'covid_cases.csv'
with open(filename, 'w', newline='') as f:
	w = csv.DictWriter(f,['country','confirmed','deaths','continent'])
	w.writeheader()
	for row in data:
		w.writerow(row)
